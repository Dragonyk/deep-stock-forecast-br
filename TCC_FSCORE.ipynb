# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

import csv
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import mean_absolute_error

# def mae(y_true, predictions):
#    y_true, predictions = np.array(y_true), np.array(predictions)
#    return np.mean(np.abs(y_true - predictions))

datasets = {
       "PETR4": [
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/PETR4.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/PETR4/06102022205520_gntwifrmme_LSTM_M1/result_gntwifrmme_PETR4_modelo_6.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/PETR4/06102022205656_gntwifrmme_LSTM_M2/result_gntwifrmme_PETR4_modelo_2.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/PETR4/06102022213559_gntwifrmme_DNN/result_gntwifrmme_PETR4_modelo_8.csv'],
       
       "VALE3": [
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/VALE3.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/VALE3/08102022003705_gntwifrmme_LSTM_M1/result_gntwifrmme_VALE3_modelo_6.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/VALE3/07102022235144_gntwifrmme_LSTM_M2/result_gntwifrmme_VALE3_modelo_2.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/VALE3/08102022003906_gntwifrmme_DNN/result_gntwifrmme_VALE3_modelo_8.csv'],
       
       "BBDC4": [
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/BBDC4.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/BBDC4/07102022224012_gntwifrmme_LSTM_M1/result_gntwifrmme_BBDC4_modelo_6.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/BBDC4/07102022220529_gntwifrmme_LSTM_M2/result_gntwifrmme_BBDC4_modelo_2.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/BBDC4/07102022224208_gntwifrmme_DNN/result_gntwifrmme_BBDC4_modelo_8.csv'],
       
       "ITUB4": [
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/ITUB4.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/ITUB4/07102022233059_gntwifrmme_LSTM_M1/result_gntwifrmme_ITUB4_modelo_6.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/ITUB4/07102022224631_gntwifrmme_LSTM_M2/result_gntwifrmme_ITUB4_modelo_2.csv',
                 '/content/drive/MyDrive/DEV/Python/Datasets/TCC/TSTs/2008-2022/ITUB4/07102022233421_gntwifrmme_DNN/result_gntwifrmme_ITUB4_modelo_8.csv']}



def read_data(csvpath):
  with open(csvpath, newline='') as f:
      reader = csv.reader(f)
      data = list(reader)
  return data

def binary_data(datalist):
  direction = [0]
  for i in range(1, len(datalist)):
    if datalist[i] > datalist[i-1]:
      direction.append(1)
    else:
      direction.append(0)
  return direction

def info(data_real_path, data_pred_path):
  data_real = read_data(data_real_path)
  data_pred = read_data(data_pred_path)

  dir_real = binary_data(data_real)
  dir_pred = binary_data(data_pred)

  print('MAE = '+str(mean_absolute_error(data_real, data_pred)))
  print('f1-score = '+str(f1_score(dir_real, dir_pred)))

# %%
print('=== PETR4 ===')
info(datasets['PETR4'][0], datasets['PETR4'][1])
info(datasets['PETR4'][0], datasets['PETR4'][2])
info(datasets['PETR4'][0], datasets['PETR4'][3])
print()

print('=== VALE3 ===')
info(datasets['VALE3'][0], datasets['VALE3'][1])
info(datasets['VALE3'][0], datasets['VALE3'][2])
info(datasets['VALE3'][0], datasets['VALE3'][3])
print()

print('=== BBDC4 ===')
info(datasets['BBDC4'][0], datasets['BBDC4'][1])
info(datasets['BBDC4'][0], datasets['BBDC4'][2])
info(datasets['BBDC4'][0], datasets['BBDC4'][3])
print()

print('=== ITUB4 ===')
info(datasets['ITUB4'][0], datasets['ITUB4'][1])
info(datasets['ITUB4'][0], datasets['ITUB4'][2])
info(datasets['ITUB4'][0], datasets['ITUB4'][3])
# Out:
# === PETR4 ===
# MAE = 0.014245708025504537
# f1-score = 0.49379310344827587
# MAE = 0.01739100753567235
# f1-score = 0.5013404825737265
# MAE = 0.027689792385424947
# f1-score = 0.5283018867924528
#
# === VALE3 ===
# MAE = 0.04055715879373635
# f1-score = 0.507670850767085
# MAE = 0.019586010427337444
# f1-score = 0.5073825503355706
# MAE = 0.03913347929825332
# f1-score = 0.5311203319502076
#
# === BBDC4 ===
# MAE = 0.018270309811798502
# f1-score = 0.4843304843304843
# MAE = 0.01924342244238094
# f1-score = 0.4801136363636363
# MAE = 0.020462900361293432
# f1-score = 0.47619047619047616
#
# === ITUB4 ===
# MAE = 0.015236257030040584
# f1-score = 0.4613180515759313
# MAE = 0.015099499119150964
# f1-score = 0.456490727532097
# MAE = 0.021057030681589952
# f1-score = 0.4662921348314607
